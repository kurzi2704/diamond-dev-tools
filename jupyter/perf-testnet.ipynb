# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
filepath = 'data/hbbft/perfTestnet/csv_run1.csv'
filepath2 = 'data/hbbft/perfTestnet/csv_run2.csv'
df = pd.read_csv(filepath)
df2 = pd.read_csv(filepath2)

# %%
df2.tail()
# Out:
#     block                                               hash       extraData  \
# 80  22879  0x2ab9329a3654621624c4c8aae1cd535d8570f30878aa...  0x506172697479
# 81  22878  0xe691731163b9141a2ff6bf9187d653b4f534f789151c...  0x506172697479
# 82  22877  0x01e3b7c166bcf70f0f0711b2a164471d0dfab17cf662...  0x506172697479
# 83  22876  0x216dc581fab503ba91a44358cc94a58f7c21484377ed...  0x506172697479
# 84  22875  0xd001a32f3c1bea5abec091b3a93863a3337e231cd7d4...  0x506172697479
#
#      timestamp                      date  duration  num_of_validators  \
# 80  1665131685  2022-10-07T08:34:45.000Z         8                 16
# 81  1665131672  2022-10-07T08:34:32.000Z        13                 16
# 82  1665131668  2022-10-07T08:34:28.000Z         4                 16
# 83  1665131666  2022-10-07T08:34:26.000Z         2                 16
# 84  1665131358  2022-10-07T08:29:18.000Z       308                 16
#
#     transaction_count  txs_per_sec
# 80                463      57.8750
# ...

# %%
plt.rcParams['figure.figsize'] = [60, 20]

# plt.plot(df.block, df.txs_per_sec)
# plt.plot(df2.block, df2.txs_per_sec)


plt.plot(df.txs_per_sec)
plt.plot(df2.txs_per_sec)

# plt.plot(df.block, df.transaction_count / 3)
